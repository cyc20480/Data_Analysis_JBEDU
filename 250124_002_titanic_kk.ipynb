# %%
# 경고 메시지 무시
import warnings
warnings.filterwarnings(action='ignore')

# %%
import pandas as pd
titanic_df = pd.read_csv('Data/titanic_kk.csv')
titanic_df.head()
# Out:
#                    PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund      Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings     Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen   Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle    Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen       Mr. William Henry\tmale\t35\t0\t0\t373450\t8....

# %%
titanic_df = pd.read_csv('Data/titanic_kk.csv', sep = '\t')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
### 데이터 분리 
print('apple','banana')
print('apple','banana', sep = '')
print('apple','banana', sep = ' ')
print('apple','banana', sep = ' ->-> ')
print('apple','banana', 'eggs', 'ham')
print('apple','banana', 'eggs', 'ham', sep = '\t')
print('apple','banana', 'eggs', 'ham', sep = '\t\t')
# Out:
# apple banana
# applebanana
# apple banana
# apple ->-> banana
# apple banana eggs ham
# apple	banana	eggs	ham
# apple		banana		eggs		ham

# %%
titanic_df.shape
# Out:
# (156, 12)

# %%
len(titanic_df)
# Out:
# 156

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          126 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
d = titanic_df.rename(columns = lambda x: x.lower())
d.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
copy1_titanic_df = titanic_df
copy1_titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.rename(columns = lambda x: x.lower(), inplace = True)
titanic_df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# copy1_titanic_df 와 titanic_df 는 Data를 공유함 (동일 memory )
copy2_titanic_df = titanic_df.copy()
copy2_titanic_df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.rename(columns = lambda x: x.upper(), inplace = True)
titanic_df.head()
# Out:
#    PASSENGERID  SURVIVED  PCLASS  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 NAME     SEX   AGE  SIBSP  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    PARCH            TICKET     FARE CABIN EMBARKED
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
copy2_titanic_df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# copy2_titanic_df 와 titanic_df 는 별도의 Data임(별도 memory)

# %%
copy2_titanic_df['gender'] = 1
copy2_titanic_df.loc[copy2_titanic_df['sex'] == 'female', 'gender'] = 0
copy2_titanic_df.head(3)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    parch            ticket     fare cabin embarked  gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0

# %%
copy2_titanic_df[['passengerid', 'fare', 'age']]
# Out:
#      passengerid     fare   age
# 0              1   7.2500  22.0
# 1              2  71.2833  38.0
# 2              3   7.9250  26.0
# 3              4  53.1000  35.0
# 4              5   8.0500  35.0
# ..           ...      ...   ...
# 151          152  66.6000  22.0
# 152          153   8.0500  55.5
# 153          154  14.5000  40.5
# 154          155   7.3125   NaN
# 155          156  61.3792  51.0
#
# [156 rows x 3 columns]

# %%
copy2_titanic_df.sort_values(by = 'age', ascending = False)
# Out:
#      passengerid  survived  pclass                            name     sex  \
# 96            97         0       1       Goldschmidt, Mr. George B    male
# 116          117         0       3            Connors, Mr. Patrick    male
# 33            34         0       2           Wheadon, Mr. Edward H    male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius    male
# 94            95         0       3               Coxon, Mr. Daniel    male
# ..           ...       ...     ...                             ...     ...
# 121          122         0       3      Moore, Mr. Leonard Charles    male
# 126          127         0       3             McMahon, Mr. Martin    male
# 128          129         1       3               Peter, Miss. Anna  female
# 140          141         0       3   Boulos, Mrs. Joseph (Sultana)  female
# 154          155         0       3           Olsen, Mr. Ole Martin    male
#
#       age  sibsp  parch      ticket     fare  cabin embarked  gender
# ...

# %%
copy2_titanic_df.sort_values(by = ['age','pclass'], ascending = False)
# Out:
#      passengerid  survived  pclass  \
# 96            97         0       1
# 116          117         0       3
# 33            34         0       2
# 54            55         0       1
# 94            95         0       3
# ..           ...       ...     ...
# 154          155         0       3
# 17            18         1       2
# 31            32         1       1
# 55            56         1       1
# 64            65         0       1
#
#                                                name     sex   age  sibsp  \
# 96                        Goldschmidt, Mr. George B    male  71.0      0
# 116                            Connors, Mr. Patrick    male  70.5      0
# 33                            Wheadon, Mr. Edward H    male  66.0      0
# 54                   Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 94                                Coxon, Mr. Daniel    male  59.0      0
# ..                                              ...     ...   ...    ...
# ...

# %%
copy2_titanic_df[copy2_titanic_df.columns[0]] # 0-번 column 내용 보기
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 151    152
# 152    153
# 153    154
# 154    155
# 155    156
# Name: passengerid, Length: 156, dtype: int64

# %%
copy2_titanic_df[:3]
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    parch            ticket     fare cabin embarked  gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0

# %%
copy2_titanic_df[0:10:2]
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 2            3         1       3
# 4            5         0       3
# 6            7         0       1
# 8            9         1       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 4                           Allen, Mr. William Henry    male  35.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    parch            ticket     fare cabin embarked  gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 4      0            373450   8.0500   NaN        S       1
# 6      0             17463  51.8625   E46        S       1
# ...

# %%
copy2_titanic_df.loc[:,'age'] # age를 Series 형식으로 가져옴
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 151    22.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: age, Length: 156, dtype: float64

# %%
copy2_titanic_df.loc[:,['age']] # age를 Data Frame형식으로 가져옴
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 151  22.0
# 152  55.5
# 153  40.5
# 154   NaN
# 155  51.0
#
# [156 rows x 1 columns]

# %%
copy2_titanic_df.pivot_table(index = 'pclass', columns = 'gender', values = 'survived')
# Out:
# gender         0         1
# pclass
# 1       1.000000  0.142857
# 2       0.916667  0.166667
# 3       0.571429  0.131148

# %%
copy2_titanic_df.groupby('survived').count()
# Out:
#           passengerid  pclass  name  sex  age  sibsp  parch  ticket  fare  \
# survived
# 0                 102     102   102  102   85    102    102     102   102
# 1                  54      54    54   54   41     54     54      54    54
#
#           cabin  embarked  gender
# survived
# 0            14       102     102
# 1            17        53      54
